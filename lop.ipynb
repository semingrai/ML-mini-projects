# %%
def wau(i):
    return i*i

# %%
wa = {}
p = [10,20,30]
num = 0
for i in p:
    wa[num] = wau(i)
    num+=50

# %%
wa
# Out:
# {0: 100, 50: 400, 100: 900}

# %%
ok = {50: 1}

# %%
ok[50]
# Out:
# 1

# %%
[]
